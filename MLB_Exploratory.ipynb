# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio

# %%
df = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/WAR_BAT_PITCH.csv', encoding='cp1250')

# %% [markdown]
# # load the dataset
# df = pd.read_csv(r'WAR_BAT_PITCH.csv', encoding='cp1250')

# %%
df.head()
# Out:
#         NAME  age  mlb_ID player_ID  year_ID team_ID  stint_ID lg_ID    G  \
# 0        NaN  NaN     NaN       NaN      NaN     NaN       NaN   NaN  NaN
# 1   A. Jones  NaN     NaN  jonesa03   1926.0      DM       0.0   NNL  1.0
# 2  A. Miller  NaN     NaN  millea02   1927.0     MRS       0.0   NNL  7.0
# 3  A. Miller  NaN     NaN  millea02   1930.0     MRS       0.0   NNL  2.0
# 4  A. Mullen  NaN     NaN  mullea01   1928.0     BBB       0.0   NNL  6.0
#
#    runs_above_avg  ...  teamRpG   oppRpG  pyth_exponent  waa_win_perc   WAA  \
# 0             NaN  ...      NaN      NaN            NaN           NaN   NaN
# 1            -0.7  ...  5.10848  5.75848          1.974        0.4412 -0.06
# 2            -2.3  ...  4.59251  4.92109          1.900        0.4672 -0.23
# 3             0.7  ...  5.91352  5.57852          2.005        0.5292  0.06
# 4            -1.8  ...  4.86758  5.06258          1.924        0.4717 -0.17
#
# ...

# %%
df
# Out:
#                      NAME   age    mlb_ID  player_ID  year_ID team_ID  \
# 0                     NaN   NaN       NaN        NaN      NaN     NaN
# 1                A. Jones   NaN       NaN   jonesa03   1926.0      DM
# 2               A. Miller   NaN       NaN   millea02   1927.0     MRS
# 3               A. Miller   NaN       NaN   millea02   1930.0     MRS
# 4               A. Mullen   NaN       NaN   mullea01   1928.0     BBB
# ...                   ...   ...       ...        ...      ...     ...
# 173720        David G˘mez  26.0       NaN  gomezda01   1928.0     PTG
# 173721  Wilbert Pritchett  31.0       NaN  pritcwi01   1928.0     PTG
# 173722        Mark Hutton  27.0  116373.0  huttoma01   1997.0     FLA
# 173723      Bill Clarkson  29.0  112371.0  clarkbi02   1928.0     BSN
# 173724         Jeff Jones  26.0  116698.0  jonesje01   1983.0     OAK
#
#         stint_ID lg_ID     G  runs_above_avg  ...  teamRpG   oppRpG  \
# ...

# %%
df = df.dropna()

# %%
# print the first few rows of the DataFrame
print(df.head())
# Out:
#             NAME   age    mlb_ID  player_ID  year_ID team_ID  stint_ID lg_ID  \
# 12  A.J. Burnett  22.0  150359.0  burnea.01   1999.0     FLA       1.0    NL
# 13  A.J. Burnett  23.0  150359.0  burnea.01   2000.0     FLA       1.0    NL
# 14  A.J. Burnett  24.0  150359.0  burnea.01   2001.0     FLA       1.0    NL
# 15  A.J. Burnett  25.0  150359.0  burnea.01   2002.0     FLA       1.0    NL
# 16  A.J. Burnett  26.0  150359.0  burnea.01   2003.0     FLA       1.0    NL
#
#        G  runs_above_avg  ...  teamRpG   oppRpG  pyth_exponent  waa_win_perc  \
# 12   7.0            -1.0  ...  4.82667  4.97381          1.916        0.4856
# 13  13.0             5.0  ...  5.43509  5.05048          1.954        0.5358
# 14  25.0            -3.2  ...  4.60519  4.73359          1.890        0.4870
# 15  29.0             0.3  ...  4.49066  4.48100          1.869        0.5010
# 16   4.0             0.6  ...  4.77884  4.62384          1.894        0.5156
#
# ...

# %%
# print the DataFrame's shape
print(df.shape)
# Out:
# (64832, 23)

# %%
df.rename(columns = {'PITCHER?':'PITCHER'}, inplace = True)
df['PITCHER'] = df['PITCHER'].apply(str)

# %%
# print the DataFrame's data types
print(df.dtypes)
# Out:
# NAME                  object
# age                  float64
# mlb_ID               float64
# player_ID             object
# year_ID              float64
# team_ID               object
# stint_ID             float64
# lg_ID                 object
# G                    float64
# runs_above_avg       float64
# runs_above_rep       float64
# WAR                  float64
# salary               float64
# teamRpG              float64
# oppRpG               float64
# pyth_exponent        float64
# waa_win_perc         float64
# WAA                  float64
# oppRpG_rep           float64
# pyth_exponent_rep    float64
# waa_win_perc_rep     float64
# WAR_rep              float64
# PITCHER               object
# dtype: object

# %%
# check for missing values
print(df.isnull().sum())
# Out:
# NAME                 0
# age                  0
# mlb_ID               0
# player_ID            0
# year_ID              0
# team_ID              0
# stint_ID             0
# lg_ID                0
# G                    0
# runs_above_avg       0
# runs_above_rep       0
# WAR                  0
# salary               0
# teamRpG              0
# oppRpG               0
# pyth_exponent        0
# waa_win_perc         0
# WAA                  0
# oppRpG_rep           0
# pyth_exponent_rep    0
# waa_win_perc_rep     0
# WAR_rep              0
# PITCHER              0
# dtype: int64

# %%
# visualize the distribution of a numeric column
plt.hist(df['age'])
plt.show()

# %%
# visualize the distribution of a categorical column
df['PITCHER'].value_counts().plot(kind='bar')
plt.show()

# %%
# calculate basic statistics for a numeric column
print(df['WAR'].describe())
# Out:
# count    64832.000000
# mean         0.877163
# std          1.788574
# min         -4.050000
# 25%         -0.090000
# 50%          0.110000
# 75%          1.380000
# max         20.450001
# Name: WAR, dtype: float64

# %%
# calculate the correlation between two numeric columns
print(df['WAR'].corr(df['age']))
# Out:
# -0.009085463883574289

# %%
# group the data by a categorical column and calculate statistics
grouped_df = df.groupby('PITCHER')['WAR'].mean()
print(grouped_df)
# Out:
# PITCHER
# 0    0.800659
# 1    1.033221
# Name: WAR, dtype: float64

# %%
# create a scatter plot to visualize the relationship between two numeric columns
plt.scatter(df['salary'], df['WAR'])
plt.xlabel('salary')
plt.ylabel('WAR')
plt.show()

# %%
# create a box plot to visualize the distribution of a numeric column
plt.boxplot(df['runs_above_rep'])
plt.ylabel('runs_above_rep')
plt.show()

# %%
# create a bar plot to visualize the mean of a numeric column for each category of a categorical column
df.groupby('PITCHER')['age'].mean().plot(kind='bar')
plt.ylabel('Average Age')
plt.show()

# %%
# create a pivot table to summarize the data
pivot_table = df.pivot_table(index='team_ID', columns='PITCHER', values='WAR', aggfunc='mean')
print(pivot_table)
# Out:
# PITCHER         0         1
# team_ID
# ANA      0.813333  1.077727
# ARI      0.575569  0.829189
# ATH      1.850000 -0.440000
# ATL      0.760026  1.057106
# BAL      0.923826  0.835350
# ...           ...       ...
# TRO      1.705714  2.453333
# WHS      0.701111  0.115000
# WSA      0.579904  0.606739
# WSH      0.819263  1.375735
# WSN      0.569979  0.829798
#
# [67 rows x 2 columns]

# %%
# create a heatmap to visualize the pivot table
plt.pcolor(pivot_table, cmap='Reds')
plt.colorbar()
plt.show()

# %%
# create a pairplot to visualize the relationships between multiple numeric columns
import seaborn as sns
sns.pairplot(df, vars=['age', 'WAR', 'salary'])
plt.show()

# %%
df = df[df["year_ID"] > 1971]

# %%
df.sort_values(by=['year_ID'], inplace=True)

# %%
df = df[df["WAR"] > 6]

# %%
df.head()
# Out:
#                  NAME   age    mlb_ID  player_ID  year_ID team_ID  stint_ID  \
# 155512     Nolan Ryan  25.0  121597.0   ryanno01   1972.0     CAL       1.0
# 143915  Steve Carlton  27.0  112008.0  carltst01   1972.0     PHI       1.0
# 124481  Mickey Lolich  31.0  117875.0  lolicmi01   1972.0     DET       1.0
# 31252      Dick Allen  30.0  110157.0  allendi01   1972.0     CHW       1.0
# 22320    Chris Speier  22.0  122573.0  speiech01   1972.0     SFG       1.0
#
#        lg_ID      G  runs_above_avg  ...  teamRpG   oppRpG  pyth_exponent  \
# 155512    AL   39.0       24.624001  ...  3.46795  2.77985          1.686
# 143915    NL   41.0       74.749001  ...  3.87737  2.15856          1.669
# 124481    AL   41.0       30.257999  ...  3.46795  2.66775          1.677
# 31252     AL  148.0       52.700001  ...  3.83315  3.46795          1.762
# 22320     NL  150.0       34.400002  ...  4.04890  3.87737          1.804
#
# ...

# %%
df['WAR_G'] = df['WAR']/df['G']

# %%
df.columns
# Out:
# Index(['NAME', 'age', 'mlb_ID', 'player_ID', 'year_ID', 'team_ID', 'stint_ID',
#        'lg_ID', 'G', 'runs_above_avg', 'runs_above_rep', 'WAR', 'salary',
#        'teamRpG', 'oppRpG', 'pyth_exponent', 'waa_win_perc', 'WAA',
#        'oppRpG_rep', 'pyth_exponent_rep', 'waa_win_perc_rep', 'WAR_rep',
#        'PITCHER', 'WAR_G'],
#       dtype='object')

# %%
px.bar(df, x='year_ID', y='WAR_G')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Generate base plot:
plot = px.bar(df, x='year_ID', y='WAR', color='WAR',
              color_continuous_scale=px.colors.diverging.RdYlGn)

# Remove colorbar:
plot.update_coloraxes(showscale=False)

# Update plotly style:
plot.update_layout(template='plotly_white')

plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Label axes:
plot.update_xaxes(title='Year',
                  dtick=1)
plot.update_yaxes(title='Wins Above Replacemen (WAR)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Update plot layout:
plot.update_layout(
    title=dict(
        text='<b>Wins Above Replacement</b>\
              <br><i><sup>A Visualization of Improvements in Baseball Statistics</sup></i>',
        x=0.085,
        y=0.95,
        font=dict(
            family='Helvetica',
            size=25,
            color='#272b4f'
        )))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Add average MPG across era:
plot.add_hline(y=df['WAR'].mean())

# Add explanation of line:
plot.add_annotation(x=.05,
                    y=0.67,
                    text="Average WAR, Since 1972",
                    textangle=0,
                    xanchor='left',
                    xref="paper",
                    yref="paper",
                    font_color='black',
                    bordercolor='black',
                    borderpad=5,
                    showarrow=True,
                    arrowhead=2,
                    bgcolor='white',
                    arrowside='end'
                    )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# BREAK -- BREAK -- BREAK

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio

# %%
df2 = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/WAR_BAT_PITCH.csv', encoding='cp1250')

# %%
df2
# Out:
#                      NAME   age    mlb_ID  player_ID  year_ID team_ID  \
# 0                     NaN   NaN       NaN        NaN      NaN     NaN
# 1                A. Jones   NaN       NaN   jonesa03   1926.0      DM
# 2               A. Miller   NaN       NaN   millea02   1927.0     MRS
# 3               A. Miller   NaN       NaN   millea02   1930.0     MRS
# 4               A. Mullen   NaN       NaN   mullea01   1928.0     BBB
# ...                   ...   ...       ...        ...      ...     ...
# 173720        David G˘mez  26.0       NaN  gomezda01   1928.0     PTG
# 173721  Wilbert Pritchett  31.0       NaN  pritcwi01   1928.0     PTG
# 173722        Mark Hutton  27.0  116373.0  huttoma01   1997.0     FLA
# 173723      Bill Clarkson  29.0  112371.0  clarkbi02   1928.0     BSN
# 173724         Jeff Jones  26.0  116698.0  jonesje01   1983.0     OAK
#
#         stint_ID lg_ID     G  runs_above_avg  ...  teamRpG   oppRpG  \
# ...

# %%
df2 = df2.dropna()

# %%
df2.rename(columns = {'PITCHER?':'PITCHER'}, inplace = True)
df2['PITCHER'] = df2['PITCHER'].apply(str)
# Out:
# <ipython-input-87-983f66d04115>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-87-983f66d04115>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2.head()
# Out:
#             NAME   age    mlb_ID  player_ID  year_ID team_ID  stint_ID lg_ID  \
# 12  A.J. Burnett  22.0  150359.0  burnea.01   1999.0     FLA       1.0    NL
# 13  A.J. Burnett  23.0  150359.0  burnea.01   2000.0     FLA       1.0    NL
# 14  A.J. Burnett  24.0  150359.0  burnea.01   2001.0     FLA       1.0    NL
# 15  A.J. Burnett  25.0  150359.0  burnea.01   2002.0     FLA       1.0    NL
# 16  A.J. Burnett  26.0  150359.0  burnea.01   2003.0     FLA       1.0    NL
#
#        G  runs_above_avg  ...  teamRpG   oppRpG  pyth_exponent  waa_win_perc  \
# 12   7.0            -1.0  ...  4.82667  4.97381          1.916        0.4856
# 13  13.0             5.0  ...  5.43509  5.05048          1.954        0.5358
# 14  25.0            -3.2  ...  4.60519  4.73359          1.890        0.4870
# 15  29.0             0.3  ...  4.49066  4.48100          1.869        0.5010
# 16   4.0             0.6  ...  4.77884  4.62384          1.894        0.5156
#
# ...

# %%
df2.dtypes
# Out:
# NAME        object
# age        float64
# WAR        float64
# year_ID    float64
# dtype: object

# %%
df2 = df2[df2["PITCHER"] == '1']

# %%
#df2 = df2[df2["player_ID"] == 'ruthba01'] 
df2 = df2[df2['age'] == 30]

# %%
#df2.sort_values(by=['year_ID'], ascending=False, inplace=True)
df2.sort_values(by=['WAR'], ascending=False, inplace=True)

# %%
df2 = df2[["NAME", "age", "WAR", "year_ID"]]

# %%
df2.head(100)
# Out:
#                      NAME   age        WAR  year_ID
# 151572         Pud Galvin  27.0  20.450001   1884.0
# 173400          Tim Keefe  26.0  19.879999   1883.0
# 136051  Old Hoss Radbourn  29.0  19.160000   1884.0
# 171032         Jim Devlin  27.0  17.680000   1876.0
# 172062         Guy Hecker  28.0  15.520000   1884.0
# ...                   ...   ...        ...      ...
# 144519   Grover Alexander  30.0   9.210000   1917.0
# 148386     Mordecai Brown  31.0   9.210000   1908.0
# 138686          Jose Rijo  28.0   9.200000   1993.0
# 149042         Bob Feller  20.0   9.190000   1939.0
# 148219       Rube Waddell  25.0   9.140000   1902.0
#
# [100 rows x 4 columns]

# %%
print(df2.groupby("NAME").ngroups)
#print(df2.groupby("NAME").groups.keys())
# Out:
# 5013

# %%
df2.agg({'WAR' : ['sum', 'min'], 'age' : ['min', 'max']})
# Out:
#               WAR   age
# sum  22035.510007   NaN
# min     -3.640000  15.0
# max           NaN  49.0

# %%
df3 = df2.groupby('NAME').agg(Mean=('WAR', np.mean),Sum=('WAR', np.sum))

# %%
df3.sort_values(by=['Mean'], ascending=False, inplace=True)

# %%
df3.head(20)
# Out:
#                         Mean         Sum
# NAME
# Jim Devlin         15.420000   30.840000
# Lady Baldwin       10.770000   10.770000
# Cy Young           10.126000   50.630001
# Al Spalding         9.370000    9.370000
# George Derby        8.720000    8.720000
# Christy Mathewson   8.013750   64.110001
# Tommy Bond          7.770000   15.540000
# Jim Whitney         7.580000   15.160000
# Noodles Hahn        7.520000   15.040000
# Eddie Cicotte       7.510000   30.040000
# Old Hoss Radbourn   7.494286   52.460000
# Bucky Walters       7.360000   14.720000
# Pud Galvin          7.275556   65.480001
# Walter Johnson      7.250000  152.250000
# Doc White           7.230000    7.230000
# Vic Willis          6.793333   20.380000
# Lefty Grove         6.661765  113.250000
# Tim Keefe           6.602500   79.229999
# Roscoe Miller       6.570000    6.570000
# Bob Caruthers       6.570000   19.710000
